# %%
# import packages
import pandas as pd
import numpy as np

# read the data
df = pd.read_csv('Car_Details.csv')

# %%
df
# Out:
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0           3.5          6         265        17           23    4451
# 1           2.0          4         200        24           31    2778
# 2           2.4          4         200        22           29    3230
# 3           3.2          6         270        20           28    3575
# 4           3.5          6         225        18           24    3880
# ..          ...        ...         ...       ...          ...     ...
# 423         2.4          5         197        21           28    3450
# 424         2.3          5         242        20           26    3450
# 425         2.9          6         268        19           26    3653
# 426         1.9          4         170        22           29    2822
# 427         2.5          5         208        20           27    3823
#
#      Wheelbase  Length   MSRP
# 0          106     189  36945
# 1          101     172  23820
# 2          105     183  26990
# ...

# %% [markdown]
# ### Technique #1: Box Plot (For numeric attributes)

# %%
# box plot.
df.boxplot(column=['Horsepower'])

# %%
#Position of the Outlier
print(np.where(df['Horsepower']>400))
# Out:
# (array([ 20, 114, 262, 270, 271, 334, 412], dtype=int64),)

# %%
outlier = np.where(df['Horsepower']>400)
outlier
# Out:
# (array([ 20, 114, 262, 270, 271, 334, 412], dtype=int64),)

# %%
df.drop(outlier[0], inplace=True)

# %%
df.shape
# Out:
# (421, 9)

# %%
df[0:30]
# Out:
#     EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0          3.5          6         265        17           23    4451
# 1          2.0          4         200        24           31    2778
# 2          2.4          4         200        22           29    3230
# 3          3.2          6         270        20           28    3575
# 4          3.5          6         225        18           24    3880
# 5          3.5          6         225        18           24    3893
# 6          3.2          6         290        17           24    3153
# 7          1.8          4         170        22           31    3252
# 8          1.8          4         170        23           30    3638
# 9          3.0          6         220        20           28    3462
# 10         3.0          6         220        17           26    3583
# 11         3.0          6         220        18           25    3627
# 12         3.0          6         220        20           27    3561
# ...
